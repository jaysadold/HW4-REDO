# %%
##[assign values to variables]

# %%
chicago_murders = 762
chicago_population = 2705000
la_murders = 294
la_population = 3976000
nyc_murders = 334
nyc_population = 8538000
sjose_murders = 47
sjose_population = 1025000

# %%
nyc_rate = (nyc_murders)/(nyc_population) *100000
nyc_rate
# Out:
# 3.911923167018037

# %%
chicago_rate = (chicago_murders)/(chicago_population) *100000
chicago_rate
# Out:
# 28.170055452865068

# %%
sjose_rate = (sjose_murders)/(sjose_population) *100000
sjose_rate
# Out:
# 4.585365853658536

# %%
la_rate = (la_murders)/(la_population) *100000
la_rate
# Out:
# 7.394366197183098

# %%
nyc = 3.911923167018037

# %%
print(nyc_rate)
# Out:
# 3.911923167018037

# %%
print(3.911923167018037)
# Out:
# 3.911923167018037

# %%
nyc = (nyc_murders)/(nyc_population) *100000

# %%
print(f"nyc is:{nyc_rate}")
# Out:
# nyc is:3.911923167018037

# %%
print (f"NYC has a murder rate of: {nyc_rate:.2F}") 
print(f"while Chicago has a murder rate of: {chicago_rate:.2F}")
print (f"and San Jose's is: {sjose_rate:.2F}")
# Out:
# NYC has a murder rate of: 3.91
# while Chicago has a murder rate of: 28.17
# and San Jose's is: 4.59
